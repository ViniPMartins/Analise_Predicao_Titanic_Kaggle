# %% [markdown]
# ### Importando e Lendo os dados

# %%
# !wget "storage.googleapis.com/kagglesdsdata/competitions/3136/26502/train.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1591897810&Signature=Mq21b9ToKzJkeeKx4nWEhjYE8%2FMW%2BoqC6NwyNsvsIOyVxWa4m90PIUdmJCjxt3ZYjME1T6FKzdECZP9x7fY8%2Fj73LoRnryCAhm1pa%2BVtMu9sdgQx5k4kT8WeGdMYYHxsD6Pce1wQGh3lSCGeTIvmN3y2BYx3bwavhOwMbx1jRMmTFknu72yu5cj2GF7eQTpyPZHRaVSVHUayAWhaV7tvmHhRWLKO0FIOX37mJgJM1NTj3NCmGCPz8t%2FR3aFEwH9wjDPo7U%2BeXY99vvuG0gNd4jtrlubGE7WZi%2B2Ps4RI%2FlA%2B4ov%2FNyUPPz0MmmJCD%2FKtg2Ozs0zcemwbLo20UOVCTA%3D%3D&response-content-disposition=attachment%3B+filename%3Dtrain.csv"
# !wget "storage.googleapis.com/kagglesdsdata/competitions/3136/26502/gender_submission.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1592093546&Signature=CS4bzLqJBN%2BflIv0EjU3zTaAbomLcg7zVphcNIiJ0BKTAY9cdKDsXMJ1Xe15kXn3nl8TIOuy7%2BKnHqkXDyxAUl6UaVQ%2Fre%2F%2FD7hVzFgTR6Tia%2BZNziSGCQB8hWaHj2VzGPWEw59pz7jhZ7%2FqtdBpruIVvu%2BEG0rO7VcZqS1HqGutxT6QWtE6Ku%2F0Xqip9Vt%2FyUswaNxGD%2BCmbXAE53P4mQ5bP1V%2B5ZMCaP0sucs%2F6OjQaA9oo0Oy3OpzZSJjfQfWMQ5qYXDs0KFhg%2FUkCH7on7V0sBq7HWfElZQfmgz%2BiCW%2F2aMdsOBTwPJAaQPUbI5ORBnYEhxBZkdXByDDpTKwUA%3D%3D&response-content-disposition=attachment%3B+filename%3Dgender_submission.csv"
# !wget "storage.googleapis.com/kagglesdsdata/competitions/3136/26502/test.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1591910166&Signature=ouNB4lHr28zCyIIBgfHlZXEHJCCMG8DUMy3NJscf2tezvmClYxkPbNXi4ZnQ9wfxDWUCsBQ4wwV8RInonA2DTfG8Fr%2Fhv2P4NZ8phLM1ZWmaMesGye0Q%2Fc45OXbtn2P65GfSUPqN2KWE5SmHKyOGYxoMZ1MfmT1Gb0y0Jo%2BMnAW97R2%2FhtJ0QodYTQKEdAG8MAhuL8WTU43sHR%2BjQR3rxGYfYwfz4g379My%2BojUcrR1uMKgojBCWwv5VmD63Dblqk4HiZLREJ%2FaH%2FukUPD%2Fov3je5wFnyDDIsWv83s39i0mbCU0UmDQuuShMpO3BxTonLF9sPxUJ1voXFz59XnFVcA%3D%3D&response-content-disposition=attachment%3B+filename%3Dtest.csv"

# %%
# !mv "train.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1591897810&Signature=Mq21b9ToKzJkeeKx4nWEhjYE8%2FMW+oqC6NwyNsvsIOyVxWa4m90PIUdmJCjxt3ZYjME1T6FKzdECZP9x7fY8%2Fj73LoRnryCAhm1pa+VtMu9sdgQx5k4kT8WeGdMYYHxsD6P" train.csv
# !mv "gender_submission.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1592093546&Signature=CS4bzLqJBN+flIv0EjU3zTaAbomLcg7zVphcNIiJ0BKTAY9cdKDsXMJ1Xe15kXn3nl8TIOuy7+KnHqkXDyxAUl6UaVQ%2Fre%2F%2FD7hVzFgTR6Tia+ZNziSGC" gender_submission.csv
# !mv "test.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1591910166&Signature=ouNB4lHr28zCyIIBgfHlZXEHJCCMG8DUMy3NJscf2tezvmClYxkPbNXi4ZnQ9wfxDWUCsBQ4wwV8RInonA2DTfG8Fr%2Fhv2P4NZ8phLM1ZWmaMesGye0Q%2Fc45OXbtn2P65GfS" teste.csv

# %%
import pandas  as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv("train.csv")
df_train
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %% [markdown]
# ### Primeiras análises

# %% [markdown]
# > A primeira análise é feita montando alguns gráficos abaixo, mostrando a quantidade de sobreviventes de acordo com algumas características.
#
#
# * É possivel observar que a quantidade de mulheres sobreviventes e expressivamente maior que o número de homens sobreviventes (gráfico 1).
#
# * Também é possivel observar uma maior quantidade de sobreviventes em pessoas que estavam na primeira classe, uma quantidade um pouco menor da segunda classe e por último, a terceira classe com o menor número de sobreviventes (gráfico 2).
#
# * Por fim, vemos a quantidade de sobreviventes por porto de embarque, que não
# será tão relevante para as próximas análises (gráfico 3).

# %%
sns.set(style="darkgrid")
def barplot(Df):
    fig, (axis1, axis2, axis3) = plt.subplots(1,3,figsize=(12,4))

    sns.barplot(x='Sex', y='Survived', data=Df, ax=axis1)
    sns.barplot(x='Pclass', y='Survived', data=Df, ax=axis2)
    sns.barplot(x='Embarked', y='Survived', data=Df, ax=axis3)

    axis1.set_title('Gráfico 1')
    axis2.set_title('Gráfico 2')
    axis3.set_title('Gráfico 3')

barplot(df_train)

# %% [markdown]
# > Na próxima análise, pode-se observar a distribuição de sobreviventes ou não por faixas de idade.
#
# > Chama a atenção o pico no gráfico de sobreviventes entre as idades de 0 a 5 anos, indicando que as crianças foram colocadas como prioridade de sobreviventes.

# %%
def compBar(Df):
    fig, (axis1, axis2) = plt.subplots(1,2, figsize=(12,4))
    sns.distplot(Df.query("Survived==1")['Age'], ax=axis1)
    sns.distplot(Df.query("Survived==0")['Age'], ax=axis2)
    axis1.set_title('Pessoas sobreviventes')
    axis2.set_title('Pessoas não sobreviventes')

    plt.show()

compBar(df_train)

# %% [markdown]
# > Abaixo está plotado uma série de gráficos, os quais podem ser extraídas diversas informações.
#
# > Uma informação bastante importante e complementar ao gráfico 2 da primeira análise é apresentada no gráfico de barras da terceira coluna e terceira linha.
#
# > Nele podemos ver que a quantidade de pessoas na terceira classe é maior em relação as outras duas classes.
#
# > Unindo a informação do gráfico 2 da primeira análise podemos observar como a quantidade de sobreviventes da terceira classe foi expressivamente baixa e como as pessoas que estavam em classes mais altas foram priorizadas na hora do salvamento.

# %%
columns = ['Parch', 'Fare', 'Pclass', 'Age']
sns.pairplot(df_train[columns])

# %% [markdown]
# Por fim, nesta primeira estapa da análise dos dados, está plotado abaixo uma matriz de correlação que confirma alguns insides obtidos anteriormente, como por exemplo:
#
# > A sobrevivência tem uma correlação negativa de -0.34 em relação classe, o que quer dizer que, quanto menor o número da classe (considerando que a primeira classe é representada por 1 e a terceira representada por 3), maior será a probabilidade de sobrevivência.

# %%
def correlacao(Df):
    fig, axis1 = plt.subplots(1,1, figsize=(20,5))
    sns.heatmap(Df.corr(), cmap='coolwarm', fmt='.2f', linewidths=0.1, vmax=1.0, square='true', linecolor='white', annot=True)
    plt.show()

correlacao(df_train)

# %% [markdown]
# ### Limpeza dos dados
#
# > Feita as primeiras análise, agora é realizada a limpeza dos dados removendo alguns outliers identificados, como mostrado nos gráficos abaixo, afim de se ter uma melhor uniformidade dos dados para os modelos de Machine Learnig.

# %%
#fig, (axis1, axis2) = plt.subplots()
df_orig = df_train[['Survived', 'Fare']]
df_orig = df_orig.round(0)
df_sct = df_train[['Survived', 'Fare']]
df_sct = df_sct.round(0)
df_sct2 = df_sct.drop(df_sct.query("Fare>=300").index)
df_sct3 = df_sct2.drop(df_sct.query("Fare==8").index)

df_orig_plot = df_orig.groupby(['Fare']).sum()
df_plot2 = df_sct2.groupby(['Fare']).sum()
df_plot3 = df_sct3.groupby(['Fare']).sum()

fig, (axis1, axis2, axis3) = plt.subplots(1,3, figsize=(16,4))

sns.scatterplot(x=df_orig_plot.index, y=df_orig_plot['Survived'].values, ax=axis1)
sns.scatterplot(x=df_plot2.index, y=df_plot2['Survived'].values, ax=axis2)
sns.scatterplot(x=df_plot3.index, y=df_plot3['Survived'].values, ax=axis3)

axis1.set(ylabel='Nº de Sobreviventes')
axis1.set_title('Original')
axis2.set_title('Eliminando 1 outlier')
axis3.set_title('Eliminando todos outliers')
plt.show()

# %%
#DataFrame salvando todos os outliers removidos

df_teste = df_train.round(0)
df_out1 = df_teste.query("Fare==8 and Survived==1")
df_out2 = df_teste.query("Fare>=300")
df_outliers = pd.concat([df_out1, df_out2])
df_outliers.head()
# Out:
#     PassengerId  Survived  Pclass  ... Fare Cabin  Embarked
# 2             3         1       3  ...  8.0   NaN         S
# 22           23         1       3  ...  8.0   NaN         Q
# 28           29         1       3  ...  8.0   NaN         Q
# 32           33         1       3  ...  8.0   NaN         Q
# 44           45         1       3  ...  8.0   NaN         Q
#
# [5 rows x 12 columns]

# %% [markdown]
# > Após a remoção dos outliers, é criada um dataFrame com os dados limpos (df_cl), e plotado novamente os dados de análise para verificarmos se a remoção dos outliers interferiu no sentido dos dados.
#
# > Comparando-os podemos observar que os dados permaneceram com a estrutura básicamente igual e que ocorreu algumas pequenas alterações.

# %%
df_cl = df_train
df_cl = df_cl.round(0)
df_cl = df_cl.drop(df_cl.query("Fare>=300").index)
df_cl = df_cl.drop(df_cl.query("Fare==8").index)

# %%
barplot(df_cl)

# %%
compBar(df_cl)

# %%
correlacao(df_cl)

# %% [markdown]
# > Nesta etapa é feita a preparação dos dados para os algorítimos, começando com a seleção das features que serão usados e montagem do DataFrame de modelo.

# %%
def limpaBase(df):
    swap = {
        'male': 0,
        'female': 1
    }

    df_mach = df.drop(['Name', 'Ticket', 'Cabin'], axis=1)
    df_mach['Sex'] = df_mach['Sex'].map(swap)
    embarked = df_mach.Embarked.str.get_dummies()
    df_mach = pd.concat([df_mach, embarked], axis=1)
    df_mach = df_mach.drop('Embarked', axis=1)
    id_med = df_mach['Age'].median()
    df_mach['Age'] = df_mach['Age'].fillna(id_med)
    df_mach.dtypes
    passengerId = df_mach['PassengerId']
    df_mach = df_mach.drop(['PassengerId'], axis=1)
    return df_mach, passengerId

df_mach, passengerId = limpaBase(df_cl)
df_mach
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch  Fare  C  Q  S
# 0           0       3    0  22.0      1      0   7.0  0  0  1
# 1           1       1    1  38.0      1      0  71.0  1  0  0
# 3           1       1    1  35.0      1      0  53.0  0  0  1
# 6           0       1    0  54.0      0      0  52.0  0  0  1
# 7           0       3    0   2.0      3      1  21.0  0  0  1
# ..        ...     ...  ...   ...    ...    ...   ... .. .. ..
# 885         0       3    1  39.0      0      5  29.0  0  1  0
# 886         0       2    0  27.0      0      0  13.0  0  0  1
# 887         1       1    1  19.0      0      0  30.0  0  0  1
# 888         0       3    1  29.0      1      2  23.0  0  0  1
# 889         1       1    0  26.0      0      0  30.0  1  0  0
#
# [682 rows x 10 columns]

# %% [markdown]
# ### Modelos de Machine Learnig

# %% [markdown]
# > É feita então a separação dos dados de treino e de teste baseando no dataFrame modelo montado anteriormente

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

x1 = df_mach.drop('Survived', axis=1)
y = df_mach.Survived

np.random.seed(42)

x = StandardScaler().fit_transform(x1)

x_train, x_test, y_train, y_test = train_test_split(x, y)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (511, 9)
# (171, 9)
# (511,)
# (171,)

# %% [markdown]
# > O primeiro algorítimo usado é um Dummy para termos uma base de acurácia.

# %%
from sklearn.dummy import DummyClassifier

rand = np.random.RandomState(42)

dummy = DummyClassifier(random_state=rand)
dummy.fit(x_train, y_train)
previsao = dummy.predict(x_test)
acuracia = dummy.score(previsao, y_test) * 100
print('A taxa de acurácia foi: %0.2f%%' % acuracia)
# Out:
# A taxa de acurácia foi: 47.95%
# /usr/local/lib/python3.6/dist-packages/sklearn/dummy.py:132: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   "stratified to prior in 0.24.", FutureWarning)

# %% [markdown]
# > Abaixo é usado um codigo que faz o teste em alguns modelos de Machine Learnig e logo em seguida e retirado a média de acuracia de cada modelo
#
# > (Esse código é usado apenas para teste e conhecimento, ele não será considerado no modelo final)

# %%
x = df_mach.drop('Survived', axis=1)
y = df_mach.Survived

# %%
print(__doc__)

modelos = []

# Code source: Gaël Varoquaux
#              Andreas Müller
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression

h = .02  # step size in the mesh

names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA", "LogisticRegres"]

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1, max_iter=1000),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis(),
    LogisticRegression()]

X, y = make_classification(n_features=2, n_redundant=0, n_informative=2,
                           random_state=1, n_clusters_per_class=1)
rng = np.random.RandomState(2)
X += 2 * rng.uniform(size=X.shape)
linearly_separable = (X, y)

datasets = [make_moons(noise=0.3, random_state=0),
            make_circles(noise=0.2, factor=0.5, random_state=1),
            linearly_separable
            ]

figure = plt.figure(figsize=(27, 9))
i = 1
# iterate over datasets
for ds_cnt, ds in enumerate(datasets):
    # preprocess dataset, split into training and test part
    X, y = ds
    X = StandardScaler().fit_transform(X)
    X_train, X_test, y_train, y_test = \
        train_test_split(X, y, test_size=.4, random_state=42)

    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    # just plot the dataset first
    cm = plt.cm.RdBu
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])
    ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
    if ds_cnt == 0:
        ax.set_title("Input data")
    # Plot the training points
    ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright,
               edgecolors='k')
    # Plot the testing points
    ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6,
               edgecolors='k')
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
    ax.set_xticks(())
    ax.set_yticks(())
    i += 1

    # iterate over classifiers
    for name, clf in zip(names, classifiers):
        ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
        clf.fit(X_train, y_train)
        score = clf.score(X_test, y_test)
        acuracia = score * 100
        modelos.append([name, acuracia])
        print(f"Modelo {name}, taxa de acurácia %.2f%%" % acuracia)

        # Plot the decision boundary. For that, we will assign a color to each
        # point in the mesh [x_min, x_max]x[y_min, y_max].
        if hasattr(clf, "decision_function"):
            Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
        else:
            Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]

        # Put the result into a color plot
        Z = Z.reshape(xx.shape)
        ax.contourf(xx, yy, Z, cmap=cm, alpha=.8)

        # Plot the training points
        ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright,
                   edgecolors='k')
        # Plot the testing points
        ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright,
                   edgecolors='k', alpha=0.6)

        ax.set_xlim(xx.min(), xx.max())
        ax.set_ylim(yy.min(), yy.max())
        ax.set_xticks(())
        ax.set_yticks(())
        if ds_cnt == 0:
            ax.set_title(name)
        ax.text(xx.max() - .3, yy.min() + .3, ('%.2f' % score).lstrip('0'),
                size=15, horizontalalignment='right')
        i += 1

plt.tight_layout()
plt.show()
# Out:
# Automatically created module for IPython interactive environment
# Modelo Nearest Neighbors, taxa de acurácia 97.50%
# Modelo Linear SVM, taxa de acurácia 87.50%
# Modelo RBF SVM, taxa de acurácia 97.50%
# Modelo Gaussian Process, taxa de acurácia 97.50%
# Modelo Decision Tree, taxa de acurácia 95.00%
# Modelo Random Forest, taxa de acurácia 95.00%
# Modelo Neural Net, taxa de acurácia 90.00%
# Modelo AdaBoost, taxa de acurácia 92.50%
# Modelo Naive Bayes, taxa de acurácia 87.50%
# Modelo QDA, taxa de acurácia 85.00%
# Modelo LogisticRegres, taxa de acurácia 87.50%
# Modelo Nearest Neighbors, taxa de acurácia 92.50%
# Modelo Linear SVM, taxa de acurácia 40.00%
# Modelo RBF SVM, taxa de acurácia 87.50%
# Modelo Gaussian Process, taxa de acurácia 90.00%
# Modelo Decision Tree, taxa de acurácia 80.00%
# Modelo Random Forest, taxa de acurácia 82.50%
# Modelo Neural Net, taxa de acurácia 90.00%
# Modelo AdaBoost, taxa de acurácia 82.50%
# Modelo Naive Bayes, taxa de acurácia 70.00%
# Modelo QDA, taxa de acurácia 72.50%
# Modelo LogisticRegres, taxa de acurácia 40.00%
# Modelo Nearest Neighbors, taxa de acurácia 92.50%
# Modelo Linear SVM, taxa de acurácia 92.50%
# Modelo RBF SVM, taxa de acurácia 95.00%
# Modelo Gaussian Process, taxa de acurácia 92.50%
# Modelo Decision Tree, taxa de acurácia 95.00%
# Modelo Random Forest, taxa de acurácia 95.00%
# Modelo Neural Net, taxa de acurácia 95.00%
# Modelo AdaBoost, taxa de acurácia 95.00%
# Modelo Naive Bayes, taxa de acurácia 95.00%
# Modelo QDA, taxa de acurácia 92.50%
# Modelo LogisticRegres, taxa de acurácia 95.00%

# %%
#Média de acurácia
data = pd.DataFrame(modelos, columns=['names', 'acuracia'])
data.groupby('names').median()
# Out:
#                    acuracia
# names
# AdaBoost               92.5
# Decision Tree          95.0
# Gaussian Process       92.5
# Linear SVM             87.5
# LogisticRegres         87.5
# Naive Bayes            87.5
# Nearest Neighbors      92.5
# Neural Net             90.0
# QDA                    85.0
# RBF SVM                95.0
# Random Forest          95.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np

x1 = df_mach.drop('Survived', axis=1)
y = df_mach.Survived

np.random.seed(42)

x = StandardScaler().fit_transform(x1)

x_train, x_test, y_train, y_test = train_test_split(x, y)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (511, 9)
# (171, 9)
# (511,)
# (171,)

# %% [markdown]
# > É feita então a escolha de três modelos a serem usados, e é possivel ver que o modelo DecisionTreeClassifier é o que obtem o melhor resultado de acurácia.

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

svc = SVC(gamma=2, C=1)
svc.fit(x_train, y_train)
predict = svc.predict(x_test)
acuracia = accuracy_score(y_test, predict)*100
print("A taxa de acurácia foi de %.2f%%" % acuracia)
# Out:
# A taxa de acurácia foi de 81.29%

# %%
from sklearn.linear_model import LogisticRegression

rand = np.random.RandomState(42)

logReg = LogisticRegression(solver='liblinear', random_state=rand)
logReg.fit(x_train, y_train)
predict = logReg.predict(x_test)
acur = accuracy_score(y_test, predict) * 100
print("A taxa de acurácia foi de %.2f%%" % acur)
# Out:
# A taxa de acurácia foi de 78.36%

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(max_depth=3)
tree.fit(x_train, y_train)
pred = tree.predict(x_test)
acur = accuracy_score(y_test, pred) * 100
print("A taxa de acurácia foi de %.2f%%" % acur)
# Out:
# A taxa de acurácia foi de 84.21%

# %% [markdown]
# > Exibição da árvore de decisão considerada pelo modelo DecisionTreeClassifier

# %%
from sklearn.tree import export_graphviz
import graphviz

features = x1.columns
dot_data = export_graphviz(tree, out_file=None,
                           filled = True, rounded = True,
                           feature_names = features,
                           class_names = ["não", "sim"])
grafico = graphviz.Source(dot_data)
grafico

# %% [markdown]
# ### Resultados Finais

# %% [markdown]
# > Para finalizar, é importado os dados de teste e feito o mesmo procedimento de limpeza dos dados mostrado anteriormente.

# %%
df_teste = pd.read_csv('teste.csv')
df_teste, passengerId = limpaBase(df_teste)
x_teste = df_teste
x_teste.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  C  Q  S
# 0       3    0  34.5      0      0   7.8292  0  1  0
# 1       3    1  47.0      1      0   7.0000  0  0  1
# 2       2    0  62.0      0      0   9.6875  0  1  0
# 3       3    0  27.0      0      0   8.6625  0  0  1
# 4       3    1  22.0      1      1  12.2875  0  0  1

# %%
#Removendo dados nulos
id_med = x_teste['Fare'].median()
x_teste['Fare'] = x_teste['Fare'].fillna(id_med)

x_teste.describe()
# Out:
#            Pclass         Sex         Age  ...           C           Q           S
# count  418.000000  418.000000  418.000000  ...  418.000000  418.000000  418.000000
# mean     2.265550    0.363636   29.599282  ...    0.244019    0.110048    0.645933
# std      0.841838    0.481622   12.703770  ...    0.430019    0.313324    0.478803
# min      1.000000    0.000000    0.170000  ...    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000   23.000000  ...    0.000000    0.000000    0.000000
# 50%      3.000000    0.000000   27.000000  ...    0.000000    0.000000    1.000000
# 75%      3.000000    1.000000   35.750000  ...    0.000000    0.000000    1.000000
# max      3.000000    1.000000   76.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 9 columns]

# %%
#Transpondo os dados para uma mesma escala de valores
x_teste = StandardScaler().fit_transform(x_teste)

# %%
y_teste = pd.read_csv('gender_submission.csv')
y_teste = y_teste['Survived']
y_teste.describe()
# Out:
# count    418.000000
# mean       0.363636
# std        0.481622
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %% [markdown]
# > Usando o modelo treinado, obtemos um resultado final de acurácia de 94,26%

# %%
pred = tree.predict(x_teste)
acur = accuracy_score(y_teste, pred) * 100
print("A taxa de acurácia foi de %.2f%%" % acur)
# Out:
# A taxa de acurácia foi de 94.26%

# %% [markdown]
# > Os dados são então exportados como csv para se fazer a submission ao kaggle

# %%
submission = pd.DataFrame({'passengerId':passengerId, 'Survived':pred})
submission.head()
# Out:
#    passengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
comparativo = pd.DataFrame({'passengerId':passengerId, 'previsao':pred, 'original':y_teste})
comparativo
# Out:
#      passengerId  previsao  original
# 0            892         0         0
# 1            893         1         1
# 2            894         0         0
# 3            895         0         0
# 4            896         1         1
# ..           ...       ...       ...
# 413         1305         0         0
# 414         1306         1         1
# 415         1307         0         0
# 416         1308         0         0
# 417         1309         0         0
#
# [418 rows x 3 columns]

# %%
submission.to_csv('./submission_lr.csv', index=False)
